# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from config import api_key
import json

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# Starting URL for Weather Map API Call
base_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" 

Query_url = base_url + api_key + "&q="
#print(base_url)
#print(Query_url)

# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the [city count to confirm sufficient count
len(cities)
# Out:
# 608

# %% [markdown]
# ## Perform API Calls

# %%
Results = []
City_Name = []
Country = []
Latitude = []
Humidity = []
Max_Temperature = []
Cloudiness = []
Wind_Speed = []
Date_Time = []
Longitude = []

for city in cities:
   
    print(f"Retrieving record for {city}:")   
    response = requests.get(Query_url + city).json()
    City_ID = response.get("id")
    if response.get("id"):
        print(f"     Record found for City: {city}    City ID: {City_ID}")
        Results.append(response)
        Latitude.append(response['coord']['lat'])
        Longitude.append(response['coord']["lon"])
        Max_Temperature.append(response['main']['temp_max'])
        Humidity.append(response['main']['humidity'])
        Cloudiness.append(response['clouds']['all'])
        Wind_Speed.append(response['wind']['speed'])
        City_Name.append(response['name'])
        Country.append(response['sys']['country'])
        Date_Time.append(response["dt"])
        
    else:
        print(f"     No information found for city: {city}")
          
print("---------------------------------------")
print("Data Retrieval Complete")
# Out:
# Retrieving record for ushuaia:
#      Record found for City: ushuaia    City ID: 3833367
# Retrieving record for busselton:
#      Record found for City: busselton    City ID: 2075265
# Retrieving record for puerto ayora:
#      Record found for City: puerto ayora    City ID: 3652764
# Retrieving record for kapaa:
#      Record found for City: kapaa    City ID: 5848280
# Retrieving record for bluff:
#      Record found for City: bluff    City ID: 2175403
# Retrieving record for tarragona:
#      Record found for City: tarragona    City ID: 3108288
# Retrieving record for sentyabrskiy:
#      No information found for city: sentyabrskiy
# Retrieving record for banjar:
#      Record found for City: banjar    City ID: 1650233
# Retrieving record for usinsk:
#      Record found for City: usinsk    City ID: 863061
# Retrieving record for faanui:
#      Record found for City: faanui    City ID: 4034551
# Retrieving record for sitka:
#      Record found for City: sitka    City ID: 4267710
# Retrieving record for cherskiy:
#      Record found for City: cherskiy    City ID: 2126199
# Retrieving record for arraial do cabo:
#      Record found for City: arraial do cabo    City ID: 3471451
# Retrieving record for dujuma:
#      No information found for city: dujuma
# Retrieving record for kavaratti:
#      Record found for City: kavaratti    City ID: 1267390
# Retrieving record for severo-kurilsk:
#      Record found for City: severo-kurilsk    City ID: 2121385
# Retrieving record for ribeira grande:
#      Record found for City: ribeira grande    City ID: 3372707
# Retrieving record for anadyr:
#      Record found for City: anadyr    City ID: 2127202
# Retrieving record for sasvad:
#      Record found for City: sasvad    City ID: 1257066
# Retrieving record for cedar city:
#      Record found for City: cedar city    City ID: 5536630
# Retrieving record for provideniya:
#      Record found for City: provideniya    City ID: 4031574
# Retrieving record for rikitea:
#      Record found for City: rikitea    City ID: 4030556
# Retrieving record for vicuna:
#      No information found for city: vicuna
# Retrieving record for klaksvik:
#      Record found for City: klaksvik    City ID: 2618795
# Retrieving record for utiroa:
#      No information found for city: utiroa
# Retrieving record for babanusah:
#      No information found for city: babanusah
# Retrieving record for chuy:
#      Record found for City: chuy    City ID: 3443061
# Retrieving record for rosarito:
#      Record found for City: rosarito    City ID: 3676604
# Retrieving record for new norfolk:
#      Record found for City: new norfolk    City ID: 2155415
# Retrieving record for louisbourg:
#      No information found for city: louisbourg
# Retrieving record for hilo:
#      Record found for City: hilo    City ID: 5855927
# Retrieving record for susanville:
#      Record found for City: susanville    City ID: 5572400
# Retrieving record for cockburn town:
#      Record found for City: cockburn town    City ID: 3576994
# Retrieving record for ahipara:
#      Record found for City: ahipara    City ID: 2194098
# Retrieving record for petropavlovskaya:
#      Record found for City: petropavlovskaya    City ID: 510171
# Retrieving record for leningradskiy:
#      Record found for City: leningradskiy    City ID: 2123814
# Retrieving record for osoyoos:
#      Record found for City: osoyoos    City ID: 6094665
# Retrieving record for huainan:
#      Record found for City: huainan    City ID: 1807681
# Retrieving record for saint-francois:
#      Record found for City: saint-francois    City ID: 2980080
# Retrieving record for punta arenas:
#      Record found for City: punta arenas    City ID: 3874787
# Retrieving record for butaritari:
#      Record found for City: butaritari    City ID: 2110227
# Retrieving record for amderma:
#      No information found for city: amderma
# Retrieving record for kieta:
#      Record found for City: kieta    City ID: 2094027
# Retrieving record for erenhot:
#      Record found for City: erenhot    City ID: 2037485
# Retrieving record for patos:
#      Record found for City: patos    City ID: 3392887
# Retrieving record for lebu:
#      Record found for City: lebu    City ID: 344979
# Retrieving record for whitehorse:
#      Record found for City: whitehorse    City ID: 6180550
# Retrieving record for mar del plata:
#      Record found for City: mar del plata    City ID: 3863379
# Retrieving record for bethel:
#      Record found for City: bethel    City ID: 5880568
# Retrieving record for umzimvubu:
#      No information found for city: umzimvubu
# Retrieving record for port-gentil:
#      Record found for City: port-gentil    City ID: 2396518
# Retrieving record for enshi:
#      Record found for City: enshi    City ID: 1811720
# Retrieving record for mataura:
#      Record found for City: mataura    City ID: 6201424
# Retrieving record for birin:
#      Record found for City: birin    City ID: 170017
# Retrieving record for puerto penasco:
#      Record found for City: puerto penasco    City ID: 3991347
# Retrieving record for atuona:
#      Record found for City: atuona    City ID: 4020109
# Retrieving record for rio brilhante:
#      Record found for City: rio brilhante    City ID: 3451241
# Retrieving record for kargil:
#      Record found for City: kargil    City ID: 1267776
# Retrieving record for vaini:
#      Record found for City: vaini    City ID: 1273574
# Retrieving record for abha:
#      Record found for City: abha    City ID: 110690
# Retrieving record for norman wells:
#      Record found for City: norman wells    City ID: 6089245
# Retrieving record for hithadhoo:
#      Record found for City: hithadhoo    City ID: 1282256
# Retrieving record for luena:
#      Record found for City: luena    City ID: 3347719
# Retrieving record for broken hill:
#      Record found for City: broken hill    City ID: 2173911
# Retrieving record for torbay:
#      Record found for City: torbay    City ID: 6167817
# Retrieving record for samarai:
#      Record found for City: samarai    City ID: 2132606
# Retrieving record for birjand:
#      Record found for City: birjand    City ID: 140463
# Retrieving record for besleney:
#      Record found for City: besleney    City ID: 576695
# Retrieving record for bonavista:
#      Record found for City: bonavista    City ID: 5905393
# Retrieving record for vizimyary:
#      No information found for city: vizimyary
# Retrieving record for pringsewu:
#      Record found for City: pringsewu    City ID: 1630639
# Retrieving record for chokurdakh:
#      Record found for City: chokurdakh    City ID: 2126123
# Retrieving record for thompson:
#      Record found for City: thompson    City ID: 6165406
# Retrieving record for zverinogolovskoye:
#      Record found for City: zverinogolovskoye    City ID: 1484943
# Retrieving record for pittsburg:
#      Record found for City: pittsburg    City ID: 5383465
# Retrieving record for nikolskoye:
#      Record found for City: nikolskoye    City ID: 546105
# Retrieving record for fairbanks:
#      Record found for City: fairbanks    City ID: 5861897
# Retrieving record for carnarvon:
#      Record found for City: carnarvon    City ID: 1014034
# Retrieving record for touros:
#      Record found for City: touros    City ID: 3386213
# Retrieving record for kavieng:
#      Record found for City: kavieng    City ID: 2094342
# Retrieving record for hermanus:
#      Record found for City: hermanus    City ID: 3366880
# Retrieving record for san francisco:
#      Record found for City: san francisco    City ID: 5391959
# Retrieving record for netarhat:
#      Record found for City: netarhat    City ID: 1261497
# Retrieving record for bandarbeyla:
#      Record found for City: bandarbeyla    City ID: 64814
# Retrieving record for tuktoyaktuk:
#      Record found for City: tuktoyaktuk    City ID: 6170031
# Retrieving record for eureka:
#      Record found for City: eureka    City ID: 5563397
# Retrieving record for vaitupu:
#      No information found for city: vaitupu
# Retrieving record for albany:
#      Record found for City: albany    City ID: 5106834
# Retrieving record for kaeo:
#      Record found for City: kaeo    City ID: 2189343
# Retrieving record for taolanaro:
#      No information found for city: taolanaro
# Retrieving record for te anau:
#      Record found for City: te anau    City ID: 2181625
# Retrieving record for hihifo:
#      No information found for city: hihifo
# Retrieving record for port blair:
#      Record found for City: port blair    City ID: 1259385
# Retrieving record for hobyo:
#      Record found for City: hobyo    City ID: 57000
# Retrieving record for garachine:
#      Record found for City: garachine    City ID: 3709361
# Retrieving record for salalah:
#      Record found for City: salalah    City ID: 286621
# Retrieving record for cape town:
#      Record found for City: cape town    City ID: 3369157
# Retrieving record for ubrique:
#      Record found for City: ubrique    City ID: 2510112
# Retrieving record for micheweni:
#      Record found for City: micheweni    City ID: 153955
# Retrieving record for belushya guba:
#      No information found for city: belushya guba
# Retrieving record for port alfred:
#      Record found for City: port alfred    City ID: 964432
# Retrieving record for lolua:
#      No information found for city: lolua
# Retrieving record for roebourne:
#      Record found for City: roebourne    City ID: 2062276
# Retrieving record for chernyshevskiy:
#      Record found for City: chernyshevskiy    City ID: 2025456
# Retrieving record for berdigestyakh:
#      Record found for City: berdigestyakh    City ID: 2026861
# Retrieving record for san quintin:
#      Record found for City: san quintin    City ID: 1688687
# Retrieving record for tevaitoa:
#      Record found for City: tevaitoa    City ID: 4033375
# Retrieving record for tuatapere:
#      Record found for City: tuatapere    City ID: 2180815
# Retrieving record for jingdezhen:
#      Record found for City: jingdezhen    City ID: 1805680
# Retrieving record for hofn:
#      Record found for City: hofn    City ID: 2630299
# Retrieving record for kaitangata:
#      Record found for City: kaitangata    City ID: 2208248
# Retrieving record for tasiilaq:
#      Record found for City: tasiilaq    City ID: 3424607
# Retrieving record for veraval:
#      Record found for City: veraval    City ID: 3031871
# Retrieving record for cururupu:
#      Record found for City: cururupu    City ID: 3401148
# Retrieving record for ballina:
#      Record found for City: ballina    City ID: 2966778
# Retrieving record for fort saint john:
#      No information found for city: fort saint john
# Retrieving record for inhambane:
#      Record found for City: inhambane    City ID: 1045114
# Retrieving record for kampot:
#      Record found for City: kampot    City ID: 1831112
# Retrieving record for kamenka:
#      Record found for City: kamenka    City ID: 553725
# Retrieving record for namibe:
#      Record found for City: namibe    City ID: 3347019
# Retrieving record for kerouane:
#      Record found for City: kerouane    City ID: 2417886
# Retrieving record for mys shmidta:
#      No information found for city: mys shmidta
# Retrieving record for gijon:
#      Record found for City: gijon    City ID: 3121424
# Retrieving record for dikson:
#      Record found for City: dikson    City ID: 1507390
# Retrieving record for saldanha:
#      Record found for City: saldanha    City ID: 2737599
# Retrieving record for lima:
#      Record found for City: lima    City ID: 3936456
# Retrieving record for igrim:
#      Record found for City: igrim    City ID: 1505965
# Retrieving record for atikokan:
#      Record found for City: atikokan    City ID: 5888001
# Retrieving record for ilulissat:
#      Record found for City: ilulissat    City ID: 3423146
# Retrieving record for aripuana:
#      Record found for City: aripuana    City ID: 3665202
# Retrieving record for luderitz:
#      Record found for City: luderitz    City ID: 3355672
# Retrieving record for pavilosta:
#      Record found for City: pavilosta    City ID: 456827
# Retrieving record for iquique:
#      Record found for City: iquique    City ID: 3887127
# Retrieving record for illoqqortoormiut:
#      No information found for city: illoqqortoormiut
# Retrieving record for esperance:
#      Record found for City: esperance    City ID: 3573739
# Retrieving record for lakes entrance:
#      Record found for City: lakes entrance    City ID: 2160735
# Retrieving record for ketchikan:
#      Record found for City: ketchikan    City ID: 5554428
# Retrieving record for marawi:
#      Record found for City: marawi    City ID: 1701054
# Retrieving record for cabatuan:
#      Record found for City: cabatuan    City ID: 1721714
# Retrieving record for tiksi:
#      Record found for City: tiksi    City ID: 2015306
# Retrieving record for necochea:
#      Record found for City: necochea    City ID: 3430443
# Retrieving record for adrar:
#      Record found for City: adrar    City ID: 2508813
# Retrieving record for hobart:
#      Record found for City: hobart    City ID: 2163355
# Retrieving record for pacific grove:
#      Record found for City: pacific grove    City ID: 5380437
# Retrieving record for kodiak:
#      Record found for City: kodiak    City ID: 4407665
# Retrieving record for kamaishi:
#      Record found for City: kamaishi    City ID: 2112444
# Retrieving record for ordu:
#      Record found for City: ordu    City ID: 741100
# Retrieving record for kabanjahe:
#      Record found for City: kabanjahe    City ID: 1214965
# Retrieving record for rio grande:
#      Record found for City: rio grande    City ID: 3451138
# Retrieving record for san lawrenz:
#      Record found for City: san lawrenz    City ID: 2562619
# Retrieving record for qaanaaq:
#      Record found for City: qaanaaq    City ID: 3831208
# Retrieving record for hlukhiv:
#      Record found for City: hlukhiv    City ID: 707758
# Retrieving record for constitucion:
#      Record found for City: constitucion    City ID: 4011743
# Retrieving record for souillac:
#      Record found for City: souillac    City ID: 3026644
# Retrieving record for nurlat:
#      Record found for City: nurlat    City ID: 516716
# Retrieving record for burica:
#      No information found for city: burica
# Retrieving record for gazojak:
#      Record found for City: gazojak    City ID: 1514792
# Retrieving record for avarua:
#      Record found for City: avarua    City ID: 4035715
# Retrieving record for mount gambier:
#      Record found for City: mount gambier    City ID: 2156643
# Retrieving record for nong phai:
#      Record found for City: nong phai    City ID: 1608191
# Retrieving record for kuminskiy:
#      Record found for City: kuminskiy    City ID: 1501429
# Retrieving record for camacha:
#      Record found for City: camacha    City ID: 2270385
# Retrieving record for bredasdorp:
#      Record found for City: bredasdorp    City ID: 1015776
# Retrieving record for sabang:
#      Record found for City: sabang    City ID: 1691355
# Retrieving record for kalmunai:
#      Record found for City: kalmunai    City ID: 1242110
# Retrieving record for carballo:
#      Record found for City: carballo    City ID: 3126369
# Retrieving record for teahupoo:
#      Record found for City: teahupoo    City ID: 4033543
# Retrieving record for jamestown:
#      Record found for City: jamestown    City ID: 2069194
# Retrieving record for atbasar:
#      Record found for City: atbasar    City ID: 1526038
# Retrieving record for samusu:
#      No information found for city: samusu
# Retrieving record for lavrentiya:
#      Record found for City: lavrentiya    City ID: 4031637
# Retrieving record for hanzhong:
#      Record found for City: hanzhong    City ID: 1808857
# Retrieving record for leh:
#      Record found for City: leh    City ID: 1264976
# Retrieving record for east london:
#      Record found for City: east london    City ID: 1006984
# Retrieving record for kiomboi:
#      Record found for City: kiomboi    City ID: 157198
# Retrieving record for fortuna:
#      Record found for City: fortuna    City ID: 2517679
# Retrieving record for attawapiskat:
#      No information found for city: attawapiskat
# Retrieving record for san julian:
#      Record found for City: san julian    City ID: 3583102
# Retrieving record for taldan:
#      Record found for City: taldan    City ID: 2015646
# Retrieving record for bur gabo:
#      No information found for city: bur gabo
# Retrieving record for yakeshi:
#      Record found for City: yakeshi    City ID: 2033536
# Retrieving record for quelimane:
#      Record found for City: quelimane    City ID: 1028434
# Retrieving record for gbarnga:
#      Record found for City: gbarnga    City ID: 2277060
# Retrieving record for siverek:
#      Record found for City: siverek    City ID: 300614
# Retrieving record for kahului:
#      Record found for City: kahului    City ID: 5847411
# Retrieving record for batagay-alyta:
#      Record found for City: batagay-alyta    City ID: 2027042
# Retrieving record for matara:
#      Record found for City: matara    City ID: 3948642
# Retrieving record for barrow:
#      Record found for City: barrow    City ID: 3833859
# Retrieving record for nouadhibou:
#      Record found for City: nouadhibou    City ID: 2377457
# Retrieving record for iralaya:
#      Record found for City: iralaya    City ID: 3608828
# Retrieving record for ngukurr:
#      No information found for city: ngukurr
# Retrieving record for sao jose da coroa grande:
#      Record found for City: sao jose da coroa grande    City ID: 3388456
# Retrieving record for taoudenni:
#      Record found for City: taoudenni    City ID: 2450173
# Retrieving record for purificacion:
#      Record found for City: purificacion    City ID: 3671208
# Retrieving record for khatanga:
#      Record found for City: khatanga    City ID: 2022572
# Retrieving record for grootfontein:
#      Record found for City: grootfontein    City ID: 3357114
# Retrieving record for fevralsk:
#      No information found for city: fevralsk
# Retrieving record for altay:
#      Record found for City: altay    City ID: 1529651
# Retrieving record for jiayuguan:
#      Record found for City: jiayuguan    City ID: 1280957
# Retrieving record for ancud:
#      Record found for City: ancud    City ID: 3899695
# Retrieving record for airai:
#      Record found for City: airai    City ID: 1651810
# Retrieving record for castro:
#      Record found for City: castro    City ID: 3896218
# Retrieving record for nanortalik:
#      Record found for City: nanortalik    City ID: 3421765
# Retrieving record for barentsburg:
#      No information found for city: barentsburg
# Retrieving record for port elizabeth:
#      Record found for City: port elizabeth    City ID: 4501427
# Retrieving record for uthal:
#      Record found for City: uthal    City ID: 1162862
# Retrieving record for kozhevnikovo:
#      Record found for City: kozhevnikovo    City ID: 1502257
# Retrieving record for cidreira:
#      Record found for City: cidreira    City ID: 3466165
# Retrieving record for geraldton:
#      Record found for City: geraldton    City ID: 5960603
# Retrieving record for deputatskiy:
#      Record found for City: deputatskiy    City ID: 2028164
# Retrieving record for atar:
#      Record found for City: atar    City ID: 2381334
# Retrieving record for matagami:
#      Record found for City: matagami    City ID: 2335713
# Retrieving record for diofior:
#      Record found for City: diofior    City ID: 2252473
# Retrieving record for laguna:
#      Record found for City: laguna    City ID: 4013704
# Retrieving record for chalus:
#      Record found for City: chalus    City ID: 139223
# Retrieving record for lasa:
#      Record found for City: lasa    City ID: 146639
# Retrieving record for baghdad:
#      Record found for City: baghdad    City ID: 98182
# Retrieving record for mahebourg:
#      Record found for City: mahebourg    City ID: 934322
# Retrieving record for sangar:
#      Record found for City: sangar    City ID: 2017215
# Retrieving record for robertson:
#      Record found for City: robertson    City ID: 3362349
# Retrieving record for mana:
#      Record found for City: mana    City ID: 789988
# Retrieving record for dunedin:
#      Record found for City: dunedin    City ID: 2191562
# Retrieving record for saskylakh:
#      Record found for City: saskylakh    City ID: 2017155
# Retrieving record for cruz grande:
#      Record found for City: cruz grande    City ID: 3530066
# Retrieving record for broome:
#      Record found for City: broome    City ID: 2656067
# Retrieving record for troitsko-pechorsk:
#      Record found for City: troitsko-pechorsk    City ID: 481548
# Retrieving record for ozinki:
#      Record found for City: ozinki    City ID: 513328
# Retrieving record for saint george:
#      Record found for City: saint george    City ID: 262462
# Retrieving record for boddam:
#      Record found for City: boddam    City ID: 2655288
# Retrieving record for victoria:
#      Record found for City: victoria    City ID: 1733782
# Retrieving record for ahuimanu:
#      Record found for City: ahuimanu    City ID: 5856516
# Retrieving record for tutoia:
#      Record found for City: tutoia    City ID: 3385899
# Retrieving record for maposeni:
#      Record found for City: maposeni    City ID: 878073
# Retrieving record for upernavik:
#      Record found for City: upernavik    City ID: 3418910
# Retrieving record for nizhneyansk:
#      No information found for city: nizhneyansk
# Retrieving record for medea:
#      Record found for City: medea    City ID: 2488835
# Retrieving record for coos bay:
#      Record found for City: coos bay    City ID: 5720495
# Retrieving record for badou:
#      Record found for City: badou    City ID: 2367660
# Retrieving record for teneguiban:
#      No information found for city: teneguiban
# Retrieving record for gushikawa:
#      Record found for City: gushikawa    City ID: 1863495
# Retrieving record for doha:
#      Record found for City: doha    City ID: 290030
# Retrieving record for fort nelson:
#      Record found for City: fort nelson    City ID: 5955902
# Retrieving record for hambantota:
#      Record found for City: hambantota    City ID: 1244926
# Retrieving record for isla mujeres:
#      Record found for City: isla mujeres    City ID: 3526756
# Retrieving record for tulun:
#      Record found for City: tulun    City ID: 2014927
# Retrieving record for taitung:
#      Record found for City: taitung    City ID: 1668295
# Retrieving record for bairiki:
#      No information found for city: bairiki
# Retrieving record for awbari:
#      Record found for City: awbari    City ID: 2219235
# Retrieving record for ndele:
#      No information found for city: ndele
# Retrieving record for cayenne:
#      Record found for City: cayenne    City ID: 3382160
# Retrieving record for ponta do sol:
#      Record found for City: ponta do sol    City ID: 3453439
# Retrieving record for nemuro:
#      Record found for City: nemuro    City ID: 2128975
# Retrieving record for uyuni:
#      Record found for City: uyuni    City ID: 3901903
# Retrieving record for mount pleasant:
#      Record found for City: mount pleasant    City ID: 4712933
# Retrieving record for nouakchott:
#      Record found for City: nouakchott    City ID: 2377450
# Retrieving record for anloga:
#      Record found for City: anloga    City ID: 2304548
# Retrieving record for port macquarie:
#      Record found for City: port macquarie    City ID: 2152659
# Retrieving record for pisco:
#      Record found for City: pisco    City ID: 3932145
# Retrieving record for colares:
#      Record found for City: colares    City ID: 2269142
# Retrieving record for saint-philippe:
#      Record found for City: saint-philippe    City ID: 6138908
# Retrieving record for mumford:
#      Record found for City: mumford    City ID: 2297810
# Retrieving record for cabo san lucas:
#      Record found for City: cabo san lucas    City ID: 3985710
# Retrieving record for riobamba:
#      Record found for City: riobamba    City ID: 3652350
# Retrieving record for wichita falls:
#      Record found for City: wichita falls    City ID: 4741752
# Retrieving record for payo:
#      Record found for City: payo    City ID: 1638775
# Retrieving record for panguna:
#      Record found for City: panguna    City ID: 2088659
# Retrieving record for skerries:
#      Record found for City: skerries    City ID: 2961461
# Retrieving record for sarkand:
#      Record found for City: sarkand    City ID: 1519691
# Retrieving record for yellowknife:
#      Record found for City: yellowknife    City ID: 6185377
# Retrieving record for pevek:
#      Record found for City: pevek    City ID: 2122090
# Retrieving record for mount isa:
#      Record found for City: mount isa    City ID: 2065594
# Retrieving record for bathsheba:
#      Record found for City: bathsheba    City ID: 3374083
# Retrieving record for alta floresta:
#      Record found for City: alta floresta    City ID: 6316343
# Retrieving record for sterling:
#      Record found for City: sterling    City ID: 4787534
# Retrieving record for mattru:
#      Record found for City: mattru    City ID: 2409215
# Retrieving record for nanakuli:
#      Record found for City: nanakuli    City ID: 5851349
# Retrieving record for matsanga:
#      No information found for city: matsanga
# Retrieving record for ishigaki:
#      Record found for City: ishigaki    City ID: 1861416
# Retrieving record for burnie:
#      Record found for City: burnie    City ID: 2173125
# Retrieving record for bowen:
#      Record found for City: bowen    City ID: 2174444
# Retrieving record for shitanjing:
#      Record found for City: shitanjing    City ID: 1794971
# Retrieving record for along:
#      Record found for City: along    City ID: 1278969
# Retrieving record for tawkar:
#      No information found for city: tawkar
# Retrieving record for richards bay:
#      Record found for City: richards bay    City ID: 962367
# Retrieving record for kerchevskiy:
#      Record found for City: kerchevskiy    City ID: 551047
# Retrieving record for zhigansk:
#      Record found for City: zhigansk    City ID: 2012530
# Retrieving record for las torres de cotillas:
#      Record found for City: las torres de cotillas    City ID: 2515219
# Retrieving record for chara:
#      Record found for City: chara    City ID: 262462
# Retrieving record for tsiroanomandidy:
#      Record found for City: tsiroanomandidy    City ID: 1054463
# Retrieving record for ngama:
#      No information found for city: ngama
# Retrieving record for takaungu:
#      Record found for City: takaungu    City ID: 179634
# Retrieving record for dakar:
#      Record found for City: dakar    City ID: 2253354
# Retrieving record for muros:
#      Record found for City: muros    City ID: 3115824
# Retrieving record for slave lake:
#      Record found for City: slave lake    City ID: 6149374
# Retrieving record for saurimo:
#      Record found for City: saurimo    City ID: 145531
# Retrieving record for loubomo:
#      No information found for city: loubomo
# Retrieving record for gomel:
#      No information found for city: gomel
# Retrieving record for belmonte:
#      Record found for City: belmonte    City ID: 8010472
# Retrieving record for vila velha:
#      Record found for City: vila velha    City ID: 6320062
# Retrieving record for atyrau:
#      Record found for City: atyrau    City ID: 610529
# Retrieving record for jawhar:
#      Record found for City: jawhar    City ID: 1269106
# Retrieving record for khani:
#      Record found for City: khani    City ID: 610864
# Retrieving record for gayny:
#      Record found for City: gayny    City ID: 561698
# Retrieving record for san cristobal:
#      Record found for City: san cristobal    City ID: 3652462
# Retrieving record for lethem:
#      Record found for City: lethem    City ID: 3379316
# Retrieving record for cozumel:
#      No information found for city: cozumel
# Retrieving record for djambala:
#      Record found for City: djambala    City ID: 2260401
# Retrieving record for oum hadjer:
#      Record found for City: oum hadjer    City ID: 2426370
# Retrieving record for sobolevo:
#      Record found for City: sobolevo    City ID: 525426
# Retrieving record for manokwari:
#      Record found for City: manokwari    City ID: 1636308
# Retrieving record for azimur:
#      No information found for city: azimur
# Retrieving record for khandyga:
#      Record found for City: khandyga    City ID: 2022773
# Retrieving record for grand river south east:
#      No information found for city: grand river south east
# Retrieving record for shingu:
#      Record found for City: shingu    City ID: 1847947
# Retrieving record for georgetown:
#      Record found for City: georgetown    City ID: 3378644
# Retrieving record for muriae:
#      Record found for City: muriae    City ID: 3456500
# Retrieving record for florida:
#      Record found for City: florida    City ID: 3558771
# Retrieving record for kodinsk:
#      Record found for City: kodinsk    City ID: 1503037
# Retrieving record for kendari:
#      Record found for City: kendari    City ID: 1640344
# Retrieving record for viborg:
#      Record found for City: viborg    City ID: 2610319
# Retrieving record for karratha:
#      Record found for City: karratha    City ID: 6620339
# Retrieving record for batetskiy:
#      Record found for City: batetskiy    City ID: 578732
# Retrieving record for araouane:
#      Record found for City: araouane    City ID: 2460954
# Retrieving record for petropavlovsk-kamchatskiy:
#      Record found for City: petropavlovsk-kamchatskiy    City ID: 2122104
# Retrieving record for poum:
#      Record found for City: poum    City ID: 787487
# Retrieving record for flinders:
#      Record found for City: flinders    City ID: 6255012
# Retrieving record for bengkulu:
#      No information found for city: bengkulu
# Retrieving record for lamu:
#      Record found for City: lamu    City ID: 1623890
# Retrieving record for thinadhoo:
#      Record found for City: thinadhoo    City ID: 1337610
# Retrieving record for hasaki:
#      Record found for City: hasaki    City ID: 2112802
# Retrieving record for whitianga:
#      Record found for City: whitianga    City ID: 2179103
# Retrieving record for sindor:
#      Record found for City: sindor    City ID: 492860
# Retrieving record for tigre:
#      Record found for City: tigre    City ID: 3427761
# Retrieving record for zacapa:
#      Record found for City: zacapa    City ID: 3587587
# Retrieving record for mecca:
#      Record found for City: mecca    City ID: 104515
# Retrieving record for banda aceh:
#      Record found for City: banda aceh    City ID: 1215502
# Retrieving record for termiz:
#      Record found for City: termiz    City ID: 1215957
# Retrieving record for taseyevo:
#      Record found for City: taseyevo    City ID: 1490058
# Retrieving record for nishihara:
#      Record found for City: nishihara    City ID: 1850144
# Retrieving record for jinchang:
#      Record found for City: jinchang    City ID: 1805733
# Retrieving record for high level:
#      Record found for City: high level    City ID: 5975004
# Retrieving record for los llanos de aridane:
#      Record found for City: los llanos de aridane    City ID: 2514651
# Retrieving record for umm bab:
#      Record found for City: umm bab    City ID: 289548
# Retrieving record for bellevue:
#      Record found for City: bellevue    City ID: 5786882
# Retrieving record for qaqortoq:
#      Record found for City: qaqortoq    City ID: 3420846
# Retrieving record for bac lieu:
#      No information found for city: bac lieu
# Retrieving record for isangel:
#      Record found for City: isangel    City ID: 2136825
# Retrieving record for bindi:
#      Record found for City: bindi    City ID: 2441482
# Retrieving record for charleston:
#      Record found for City: charleston    City ID: 4801859
# Retrieving record for kulhudhuffushi:
#      Record found for City: kulhudhuffushi    City ID: 1337613
# Retrieving record for omsukchan:
#      Record found for City: omsukchan    City ID: 2122493
# Retrieving record for trujillo:
#      Record found for City: trujillo    City ID: 3691175
# Retrieving record for ozgon:
#      No information found for city: ozgon
# Retrieving record for porto novo:
#      Record found for City: porto novo    City ID: 6322184
# Retrieving record for lata:
#      Record found for City: lata    City ID: 1253628
# Retrieving record for mednogorsk:
#      Record found for City: mednogorsk    City ID: 528109
# Retrieving record for sinop:
#      Record found for City: sinop    City ID: 739600
# Retrieving record for road town:
#      Record found for City: road town    City ID: 3577430
# Retrieving record for oswiecim:
#      Record found for City: oswiecim    City ID: 3089658
# Retrieving record for toyooka:
#      Record found for City: toyooka    City ID: 1849831
# Retrieving record for sungairaya:
#      Record found for City: sungairaya    City ID: 1625908
# Retrieving record for ossora:
#      Record found for City: ossora    City ID: 2122389
# Retrieving record for lao cai:
#      Record found for City: lao cai    City ID: 1576303
# Retrieving record for vardo:
#      Record found for City: vardo    City ID: 4372777
# Retrieving record for grand gaube:
#      Record found for City: grand gaube    City ID: 934479
# Retrieving record for abapo:
#      Record found for City: abapo    City ID: 3924668
# Retrieving record for itapirapua:
#      Record found for City: itapirapua    City ID: 3460697
# Retrieving record for casablanca:
#      Record found for City: casablanca    City ID: 2553604
# Retrieving record for shimanovsk:
#      Record found for City: shimanovsk    City ID: 2016701
# Retrieving record for adelaide:
#      Record found for City: adelaide    City ID: 2078025
# Retrieving record for portland:
#      Record found for City: portland    City ID: 5746545
# Retrieving record for talnakh:
#      Record found for City: talnakh    City ID: 1490256
# Retrieving record for ust-kamchatsk:
#      No information found for city: ust-kamchatsk
# Retrieving record for burkhala:
#      No information found for city: burkhala
# Retrieving record for socond:
#      Record found for City: socond    City ID: 666576
# Retrieving record for tuggurt:
#      No information found for city: tuggurt
# Retrieving record for maceio:
#      Record found for City: maceio    City ID: 3395981
# Retrieving record for thasra:
#      Record found for City: thasra    City ID: 1254624
# Retrieving record for kutum:
#      Record found for City: kutum    City ID: 371745
# Retrieving record for arkhangelsk:
#      Record found for City: arkhangelsk    City ID: 581049
# Retrieving record for dibulla:
#      Record found for City: dibulla    City ID: 3685223
# Retrieving record for gurskoye:
#      No information found for city: gurskoye
# Retrieving record for tubuala:
#      Record found for City: tubuala    City ID: 3700393
# Retrieving record for santa rosa:
#      Record found for City: santa rosa    City ID: 3835994
# Retrieving record for nalut:
#      Record found for City: nalut    City ID: 2214433
# Retrieving record for odweyne:
#      No information found for city: odweyne
# Retrieving record for mount darwin:
#      Record found for City: mount darwin    City ID: 885800
# Retrieving record for nome:
#      Record found for City: nome    City ID: 4732862
# Retrieving record for hwange:
#      Record found for City: hwange    City ID: 889942
# Retrieving record for saleaula:
#      No information found for city: saleaula
# Retrieving record for marzuq:
#      Record found for City: marzuq    City ID: 72181
# Retrieving record for houma:
#      Record found for City: houma    City ID: 1784874
# Retrieving record for komsomolskiy:
#      Record found for City: komsomolskiy    City ID: 1486910
# Retrieving record for coquimbo:
#      Record found for City: coquimbo    City ID: 3893629
# Retrieving record for lucapa:
#      Record found for City: lucapa    City ID: 145724
# Retrieving record for abonnema:
#      Record found for City: abonnema    City ID: 2324433
# Retrieving record for chapais:
#      Record found for City: chapais    City ID: 5919850
# Retrieving record for rudolstadt:
#      Record found for City: rudolstadt    City ID: 2843355
# Retrieving record for pouebo:
#      Record found for City: pouebo    City ID: 2138607
# Retrieving record for tsihombe:
#      No information found for city: tsihombe
# Retrieving record for longyearbyen:
#      Record found for City: longyearbyen    City ID: 2729907
# Retrieving record for mascali:
#      Record found for City: mascali    City ID: 2524237
# Retrieving record for san-pedro:
#      Record found for City: san-pedro    City ID: 2282006
# Retrieving record for safaga:
#      No information found for city: safaga
# Retrieving record for benguela:
#      Record found for City: benguela    City ID: 3351663
# Retrieving record for qinzhou:
#      Record found for City: qinzhou    City ID: 1797551
# Retrieving record for ixtapa:
#      Record found for City: ixtapa    City ID: 4004293
# Retrieving record for ambilobe:
#      Record found for City: ambilobe    City ID: 1082243
# Retrieving record for coolum beach:
#      Record found for City: coolum beach    City ID: 2170581
# Retrieving record for yamada:
#      Record found for City: yamada    City ID: 1849876
# Retrieving record for margate:
#      Record found for City: margate    City ID: 2158744
# Retrieving record for aksu:
#      Record found for City: aksu    City ID: 1524298
# Retrieving record for moose factory:
#      Record found for City: moose factory    City ID: 6078372
# Retrieving record for baykit:
#      Record found for City: baykit    City ID: 1510689
# Retrieving record for asosa:
#      Record found for City: asosa    City ID: 343292
# Retrieving record for safaqis:
#      No information found for city: safaqis
# Retrieving record for brookhaven:
#      Record found for City: brookhaven    City ID: 5110292
# Retrieving record for yar-sale:
#      Record found for City: yar-sale    City ID: 1486321
# Retrieving record for sorvag:
#      No information found for city: sorvag
# Retrieving record for farah:
#      Record found for City: farah    City ID: 1142264
# Retrieving record for clyde river:
#      Record found for City: clyde river    City ID: 5924351
# Retrieving record for teguise:
#      Record found for City: teguise    City ID: 2510573
# Retrieving record for ponta pora:
#      Record found for City: ponta pora    City ID: 3453150
# Retrieving record for antofagasta:
#      Record found for City: antofagasta    City ID: 3899539
# Retrieving record for iskateley:
#      Record found for City: iskateley    City ID: 866062
# Retrieving record for tumannyy:
#      No information found for city: tumannyy
# Retrieving record for naryan-mar:
#      Record found for City: naryan-mar    City ID: 523392
# Retrieving record for karpathos:
#      Record found for City: karpathos    City ID: 260895
# Retrieving record for dawson creek:
#      Record found for City: dawson creek    City ID: 5935804
# Retrieving record for hami:
#      Record found for City: hami    City ID: 1529484
# Retrieving record for killarney:
#      Record found for City: killarney    City ID: 2161441
# Retrieving record for irbil:
#      No information found for city: irbil
# Retrieving record for manggar:
#      Record found for City: manggar    City ID: 1636426
# Retrieving record for penzance:
#      Record found for City: penzance    City ID: 2640377
# Retrieving record for alofi:
#      Record found for City: alofi    City ID: 4036284
# Retrieving record for loandjili:
#      Record found for City: loandjili    City ID: 2258378
# Retrieving record for manyana:
#      Record found for City: manyana    City ID: 2145554
# Retrieving record for mhasla:
#      Record found for City: mhasla    City ID: 1255619
# Retrieving record for haines junction:
#      Record found for City: haines junction    City ID: 5969025
# Retrieving record for buchanan:
#      Record found for City: buchanan    City ID: 2278158
# Retrieving record for santa teresa:
#      Record found for City: santa teresa    City ID: 3627047
# Retrieving record for vestmannaeyjar:
#      Record found for City: vestmannaeyjar    City ID: 3412093
# Retrieving record for jardim:
#      Record found for City: jardim    City ID: 3460087
# Retrieving record for kinablangan:
#      Record found for City: kinablangan    City ID: 1708743
# Retrieving record for faya:
#      Record found for City: faya    City ID: 110690
# Retrieving record for mayumba:
#      Record found for City: mayumba    City ID: 2399001
# Retrieving record for praya:
#      Record found for City: praya    City ID: 1630662
# Retrieving record for yuzhno-yeniseyskiy:
#      No information found for city: yuzhno-yeniseyskiy
# Retrieving record for dingle:
#      Record found for City: dingle    City ID: 1714733
# Retrieving record for otradnoye:
#      Record found for City: otradnoye    City ID: 513898
# Retrieving record for vila:
#      Record found for City: vila    City ID: 3164565
# Retrieving record for luwuk:
#      Record found for City: luwuk    City ID: 1637001
# Retrieving record for catio:
#      Record found for City: catio    City ID: 2373526
# Retrieving record for chicama:
#      Record found for City: chicama    City ID: 3698359
# Retrieving record for merrill:
#      Record found for City: merrill    City ID: 5572979
# Retrieving record for karaton:
#      Record found for City: karaton    City ID: 1630058
# Retrieving record for amahai:
#      Record found for City: amahai    City ID: 1651591
# Retrieving record for kamenskoye:
#      No information found for city: kamenskoye
# Retrieving record for bosaso:
#      Record found for City: bosaso    City ID: 64013
# Retrieving record for ikom:
#      Record found for City: ikom    City ID: 2338242
# Retrieving record for canora:
#      Record found for City: canora    City ID: 5915098
# Retrieving record for leshukonskoye:
#      Record found for City: leshukonskoye    City ID: 535839
# Retrieving record for cap malheureux:
#      Record found for City: cap malheureux    City ID: 934649
# Retrieving record for sorland:
#      Record found for City: sorland    City ID: 3137469
# Retrieving record for xining:
#      Record found for City: xining    City ID: 1788852
# Retrieving record for yaan:
#      Record found for City: yaan    City ID: 2338660
# Retrieving record for north bend:
#      Record found for City: north bend    City ID: 5742974
# Retrieving record for livingston:
#      Record found for City: livingston    City ID: 4073383
# Retrieving record for walvis bay:
#      Record found for City: walvis bay    City ID: 3359638
# Retrieving record for saint simons:
#      Record found for City: saint simons    City ID: 4220862
# Retrieving record for vao:
#      Record found for City: vao    City ID: 588365
# Retrieving record for puerto del rosario:
#      Record found for City: puerto del rosario    City ID: 2512186
# Retrieving record for aitape:
#      Record found for City: aitape    City ID: 2101169
# Retrieving record for liwale:
#      Record found for City: liwale    City ID: 155921
# Retrieving record for cumana:
#      Record found for City: cumana    City ID: 3644768
# Retrieving record for miri:
#      Record found for City: miri    City ID: 2347470
# Retrieving record for baruun-urt:
#      Record found for City: baruun-urt    City ID: 2032614
# Retrieving record for mercedes:
#      Record found for City: mercedes    City ID: 3441684
# Retrieving record for weiden:
#      Record found for City: weiden    City ID: 2813039
# Retrieving record for taloqan:
#      Record found for City: taloqan    City ID: 1123004
# Retrieving record for port hardy:
#      Record found for City: port hardy    City ID: 6111862
# Retrieving record for felidhoo:
#      No information found for city: felidhoo
# Retrieving record for afyonkarahisar:
#      Record found for City: afyonkarahisar    City ID: 325303
# Retrieving record for genhe:
#      Record found for City: genhe    City ID: 2037252
# Retrieving record for turtas:
#      Record found for City: turtas    City ID: 1540475
# Retrieving record for chifeng:
#      Record found for City: chifeng    City ID: 2038067
# Retrieving record for la ronge:
#      Record found for City: la ronge    City ID: 6050066
# Retrieving record for drummondville:
#      Record found for City: drummondville    City ID: 5942845
# Retrieving record for artvin:
#      Record found for City: artvin    City ID: 751816
# Retrieving record for cornwall:
#      Record found for City: cornwall    City ID: 5928065
# Retrieving record for avera:
#      Record found for City: avera    City ID: 4231997
# Retrieving record for katsuura:
#      Record found for City: katsuura    City ID: 1865309
# Retrieving record for lahat:
#      Record found for City: lahat    City ID: 1638775
# Retrieving record for usakos:
#      Record found for City: usakos    City ID: 3352461
# Retrieving record for gorshechnoye:
#      Record found for City: gorshechnoye    City ID: 559400
# Retrieving record for sambava:
#      Record found for City: sambava    City ID: 1056899
# Retrieving record for karkaralinsk:
#      No information found for city: karkaralinsk
# Retrieving record for pitimbu:
#      Record found for City: pitimbu    City ID: 3391889
# Retrieving record for trinidad:
#      Record found for City: trinidad    City ID: 3439749
# Retrieving record for kaya:
#      No information found for city: kaya
# Retrieving record for tura:
#      Record found for City: tura    City ID: 1254046
# Retrieving record for esso:
#      Record found for City: esso    City ID: 2125711
# Retrieving record for sovetskiy:
#      Record found for City: sovetskiy    City ID: 490040
# Retrieving record for obo:
#      Record found for City: obo    City ID: 236950
# Retrieving record for gillette:
#      Record found for City: gillette    City ID: 5826027
# Retrieving record for palabuhanratu:
#      No information found for city: palabuhanratu
# Retrieving record for caluquembe:
#      Record found for City: caluquembe    City ID: 3351024
# Retrieving record for lompoc:
#      Record found for City: lompoc    City ID: 5367788
# Retrieving record for labutta:
#      No information found for city: labutta
# Retrieving record for cooma:
#      Record found for City: cooma    City ID: 2170577
# Retrieving record for san patricio:
#      Record found for City: san patricio    City ID: 3437029
# Retrieving record for bogandinskiy:
#      Record found for City: bogandinskiy    City ID: 1509902
# Retrieving record for mubende:
#      Record found for City: mubende    City ID: 228971
# Retrieving record for bambous virieux:
#      Record found for City: bambous virieux    City ID: 1106677
# Retrieving record for sao marcos:
#      Record found for City: sao marcos    City ID: 3448533
# Retrieving record for mitzic:
#      Record found for City: mitzic    City ID: 2398283
# Retrieving record for dzhusaly:
#      No information found for city: dzhusaly
# Retrieving record for lodja:
#      Record found for City: lodja    City ID: 211647
# Retrieving record for methoni:
#      Record found for City: methoni    City ID: 257122
# Retrieving record for bababe:
#      No information found for city: bababe
# Retrieving record for kaihua:
#      Record found for City: kaihua    City ID: 1789001
# Retrieving record for hualmay:
#      Record found for City: hualmay    City ID: 3939761
# Retrieving record for hamilton:
#      Record found for City: hamilton    City ID: 5969785
# Retrieving record for dupnica:
#      No information found for city: dupnica
# Retrieving record for northam:
#      Record found for City: northam    City ID: 2641434
# Retrieving record for yerbogachen:
#      Record found for City: yerbogachen    City ID: 2012956
# Retrieving record for middlebury:
#      Record found for City: middlebury    City ID: 5238499
# Retrieving record for turbat:
#      Record found for City: turbat    City ID: 1163054
# Retrieving record for constantine:
#      Record found for City: constantine    City ID: 2501152
# Retrieving record for altamira:
#      Record found for City: altamira    City ID: 3407882
# Retrieving record for corn island:
#      Record found for City: corn island    City ID: 3620266
# Retrieving record for peru:
#      Record found for City: peru    City ID: 4905770
# Retrieving record for aklavik:
#      Record found for City: aklavik    City ID: 5882953
# Retrieving record for abu samrah:
#      Record found for City: abu samrah    City ID: 172515
# Retrieving record for vernon:
#      Record found for City: vernon    City ID: 6173864
# Retrieving record for beitbridge:
#      Record found for City: beitbridge    City ID: 895269
# Retrieving record for korla:
#      No information found for city: korla
# Retrieving record for mandurah:
#      Record found for City: mandurah    City ID: 2067119
# Retrieving record for shelburne:
#      Record found for City: shelburne    City ID: 6145890
# Retrieving record for vostok:
#      Record found for City: vostok    City ID: 2013279
# Retrieving record for kemin:
#      Record found for City: kemin    City ID: 1528606
# Retrieving record for geylegphug:
#      No information found for city: geylegphug
# Retrieving record for tarauaca:
#      Record found for City: tarauaca    City ID: 3661980
# Retrieving record for solin:
#      Record found for City: solin    City ID: 3190359
# Retrieving record for meadow lake:
#      Record found for City: meadow lake    City ID: 6071421
# Retrieving record for batagay:
#      Record found for City: batagay    City ID: 2027044
# Retrieving record for edd:
#      Record found for City: edd    City ID: 338345
# Retrieving record for vanimo:
#      Record found for City: vanimo    City ID: 2084442
# Retrieving record for bara:
#      Record found for City: bara    City ID: 2347758
# Retrieving record for nawa:
#      Record found for City: nawa    City ID: 1261647
# Retrieving record for malindi:
#      Record found for City: malindi    City ID: 187968
# Retrieving record for mugur-aksy:
#      Record found for City: mugur-aksy    City ID: 1498283
# Retrieving record for taburi:
#      No information found for city: taburi
# Retrieving record for zaysan:
#      Record found for City: zaysan    City ID: 1517060
# Retrieving record for sinnamary:
#      Record found for City: sinnamary    City ID: 3380290
# Retrieving record for orillia:
#      Record found for City: orillia    City ID: 6094325
# Retrieving record for xiuyan:
#      Record found for City: xiuyan    City ID: 2033602
# Retrieving record for ondorhaan:
#      No information found for city: ondorhaan
# Retrieving record for banyo:
#      Record found for City: banyo    City ID: 2234794
# Retrieving record for mehamn:
#      Record found for City: mehamn    City ID: 778707
# Retrieving record for onalaska:
#      Record found for City: onalaska    City ID: 5265702
# Retrieving record for formoso do araguaia:
#      No information found for city: formoso do araguaia
# Retrieving record for urumita:
#      Record found for City: urumita    City ID: 3666381
# Retrieving record for brae:
#      Record found for City: brae    City ID: 2654970
# Retrieving record for mackenzie:
#      Record found for City: mackenzie    City ID: 6063191
# Retrieving record for werda:
#      Record found for City: werda    City ID: 2810970
# Retrieving record for cagayan de tawi-tawi:
#      No information found for city: cagayan de tawi-tawi
# Retrieving record for san antonio:
#      Record found for City: san antonio    City ID: 3872395
# Retrieving record for solnechnyy:
#      Record found for City: solnechnyy    City ID: 2016307
# Retrieving record for manicore:
#      Record found for City: manicore    City ID: 3663503
# Retrieving record for guerrero negro:
#      Record found for City: guerrero negro    City ID: 4021858
# Retrieving record for rtishchevo:
#      Record found for City: rtishchevo    City ID: 500886
# Retrieving record for westport:
#      Record found for City: westport    City ID: 2960970
# Retrieving record for kaputa:
#      Record found for City: kaputa    City ID: 176758
# Retrieving record for tidore:
#      No information found for city: tidore
# Retrieving record for quatre cocos:
#      Record found for City: quatre cocos    City ID: 1106643
# Retrieving record for asyut:
#      Record found for City: asyut    City ID: 359783
# Retrieving record for abu dhabi:
#      Record found for City: abu dhabi    City ID: 292968
# Retrieving record for kaspiysk:
#      Record found for City: kaspiysk    City ID: 551847
# Retrieving record for awjilah:
#      Record found for City: awjilah    City ID: 88533
# Retrieving record for calabozo:
#      Record found for City: calabozo    City ID: 3647444
# Retrieving record for luebo:
#      Record found for City: luebo    City ID: 210939
# Retrieving record for kattivakkam:
#      Record found for City: kattivakkam    City ID: 1267433
# Retrieving record for kismayo:
#      No information found for city: kismayo
# Retrieving record for bardiyah:
#      No information found for city: bardiyah
# Retrieving record for doka:
#      Record found for City: doka    City ID: 376332
# Retrieving record for pangnirtung:
#      Record found for City: pangnirtung    City ID: 6096551
# Retrieving record for aasiaat:
#      Record found for City: aasiaat    City ID: 3424901
# Retrieving record for bilibino:
#      Record found for City: bilibino    City ID: 2126682
# Retrieving record for bud:
#      Record found for City: bud    City ID: 7626370
# Retrieving record for bilma:
#      Record found for City: bilma    City ID: 2446796
# Retrieving record for oyama:
#      Record found for City: oyama    City ID: 1853483
# Retrieving record for valley city:
#      Record found for City: valley city    City ID: 5062292
# Retrieving record for jalu:
#      Record found for City: jalu    City ID: 86049
# Retrieving record for honningsvag:
#      Record found for City: honningsvag    City ID: 779554
# Retrieving record for skibbereen:
#      Record found for City: skibbereen    City ID: 2961459
# Retrieving record for nelson bay:
#      Record found for City: nelson bay    City ID: 2155562
# Retrieving record for canatlan:
#      Record found for City: canatlan    City ID: 4015683
# Retrieving record for sampit:
#      Record found for City: sampit    City ID: 1628884
# Retrieving record for yenagoa:
#      Record found for City: yenagoa    City ID: 2318123
# Retrieving record for zaraza:
#      Record found for City: zaraza    City ID: 3625066
# Retrieving record for zyryanka:
#      Record found for City: zyryanka    City ID: 2119283
# Retrieving record for gazli:
#      Record found for City: gazli    City ID: 1513990
# Retrieving record for venice:
#      Record found for City: venice    City ID: 4176380
# Retrieving record for anori:
#      Record found for City: anori    City ID: 3665315
# Retrieving record for umm kaddadah:
#      Record found for City: umm kaddadah    City ID: 364933
# Retrieving record for kharitonovo:
#      Record found for City: kharitonovo    City ID: 550574
# Retrieving record for kalemie:
#      Record found for City: kalemie    City ID: 214974
# Retrieving record for porto de moz:
#      Record found for City: porto de moz    City ID: 3391387
# Retrieving record for karpogory:
#      Record found for City: karpogory    City ID: 552256
# Retrieving record for luau:
#      Record found for City: luau    City ID: 876177
# ---------------------------------------
# Data Retrieval Complete

# %%
Weather_Dict = {"City": City_Name, "Country": Country, "Latitude": Latitude, "Longitude": Longitude,
                "Max_Temperature": Max_Temperature,
                "Humidity": Humidity,
                "Cloudiness": Cloudiness,
                "Wind_Speed": Wind_Speed}

Weather_Data = pd.DataFrame(Weather_Dict)
Weather_Data = Weather_Data[["City", "Country", "Latitude", "Longitude", "Max_Temperature", "Humidity", "Cloudiness", "Wind_Speed"]]
Weather_Data.head()
# Out:
#            City Country  Latitude  Longitude  Max_Temperature  Humidity  \
# 0       Ushuaia      AR    -54.81     -68.31            33.80        80
# 1     Busselton      AU    -33.64     115.35            55.20       100
# 2  Puerto Ayora      EC     -0.74     -90.35            75.20        69
# 3         Kapaa      US     22.08    -159.32            84.20        70
# 4         Bluff      AU    -23.58     149.07            69.24        68
#
#    Cloudiness  Wind_Speed
# 0          90       25.28
# 1          48       28.10
# 2          40       20.80
# 3          75       20.80
# 4           0        4.05

# %%
print(Query_url)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3b55ad4d8390> in <module>()
# ----> 1 print(Query_url)
#
# NameError: name 'Query_url' is not defined

# %%
Weather_Data.to_csv("Weather_Data.csv")

# %%
Above = Weather_Data.loc[Weather_Data['Latitude'] > 0]
Below = Weather_Data.loc[Weather_Data['Latitude'] < 0]

Above_Equator = len(Above)
Below_Equator = len(Below)

print(f'There are {Above_Equator} sample cities above the equator and {Below_Equator} sample cities below the equator')
# Out:
# There are 381 sample cities above the equator and 160 sample cities below the equator

# %%
Date = Date_Time[0]
Time_Stamp = time.strftime("%Z - %Y/%m/%d, %H:%M:%S", time.localtime(float(Date)))

# %%
# * Sample City Latitude and Longitude

Wind_Lat = plt.scatter(Weather_Data["Longitude"], Weather_Data["Latitude"], c="blue", 
                       marker="o", s=15, edgecolors="black", alpha=0.75)
plt.title(f"Sample City Longitude and Latitude {Time_Stamp}")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.style.use('ggplot')
plt.yticks(np.arange(-80, 120, 20))
plt.xticks(np.arange(-180, 210, 30))
plt.axhline(linewidth=2, color='r')

plt.savefig("Sample City Latitude and Longitude.png")

# %%
# * Temperature (F) vs. Latitude

Temp_Lat = plt.scatter(Weather_Data["Latitude"], Weather_Data["Max_Temperature"], c="blue", 
                       marker="o", s=10, edgecolors="black", alpha=1)
plt.title(f"City Latitude vs. Max Temperature {Time_Stamp}")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.tight_layout()
plt.style.use('ggplot')
plt.xticks(np.arange(-80, 120, 20))
plt.yticks(np.arange(0, 140, 20))

plt.savefig("City Latitude vs Max Temp.png")

# %%
# * Humidity (%) vs. Latitude

Hum_Lat = plt.scatter(Weather_Data["Latitude"], Weather_Data["Humidity"], c="blue", 
                      marker="o", s=20, edgecolors="black", alpha=0.95,)
plt.title(f"City Latitude vs. Humidity {Time_Stamp}")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.tight_layout()
plt.style.use('ggplot')
plt.xticks(np.arange(-80, 120, 20))
plt.yticks(np.arange(-20, 140, 20))

plt.savefig("City Latitude vs Humidity.png")

# %%
# * Cloudiness (%) vs. Latitude

Cloud_Lat = plt.scatter(Weather_Data["Latitude"], Weather_Data["Cloudiness"], c="blue", 
                        marker="o", s=10, edgecolors="black", alpha=1)
plt.title(f"City Latitude vs. Cloudiness {Time_Stamp}")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.tight_layout()
plt.style.use('ggplot')
plt.xticks(np.arange(-80, 120, 20))
plt.yticks(np.arange(-20, 140, 20))

plt.savefig("City Latitude vs Cloudiness.png")

# %%
# * Wind Speed (mph) vs. Latitude

Wind_Lat = plt.scatter(Weather_Data["Latitude"], Weather_Data["Wind_Speed"], c="blue", 
                       marker="o", s=15, edgecolors="black", alpha=0.75)
plt.title(f"City Latitude vs. Wind Speed {Time_Stamp}")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.style.use('ggplot')
plt.xticks(np.arange(-80, 120, 20))
plt.yticks(np.arange(-5, 45, 5))

plt.savefig("City Latitude vs Wind Speed.png")

# %%
# OBSERVATIONS:

#  1. Finding average or max yearly temperature and comparing to latitude would be 
#     interesting to graph when looking at this question. Depending on the time of year the current
#     data is pulled would slighlty modify these graphs depending on current which season is currently going on.

#  2. Latitude appeared to be important when looking at temperature, but wind speed 
#     and cloudiness did not to seem as critical to latitude 

#  3. For this given date sample, humidity appears to peak around 20-40 degrees of away 
#     from the equator, with a minimal amount of humidity noted closest to the equator
